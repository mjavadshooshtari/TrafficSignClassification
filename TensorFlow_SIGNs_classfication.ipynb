# %% [markdown]
# ## 1 - Import packages

# %% [markdown]
# **Exercise**: Please mount your Google drive, and set up your working folder here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# start your code here
os.chdir("/content/drive/MyDrive/Deep learning/Homework6/Homework6") # change your working folder here

# end your code here

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
from tf_utils import load_dataset, random_mini_batches, convert_to_one_hot, predict

# %matplotlib inline
np.random.seed(123)
tf.random.set_seed(123)

# %% [markdown]
# # 2 - Problem statement: SIGNS Dataset
#
# One afternoon, with some friends we decided to teach our computers to decipher sign language. We spent a few hours taking pictures in front of a white wall and came up with the following dataset. It's now your job to build an algorithm that would facilitate communications from a speech-impaired person to someone who doesn't understand sign language.
#
# - **Training set**: 1080 pictures (64 by 64 pixels) of signs representing numbers from 0 to 5 (180 pictures per number).
# - **Test set**: 120 pictures (64 by 64 pixels) of signs representing numbers from 0 to 5 (20 pictures per number).
#
# Note that this is a subset of the SIGNS dataset. The complete dataset contains many more signs.
#
# Here are examples for each number, and how an explanation of how we represent the labels. These are the original pictures, before we lowered the image resolutoion to 64 by 64 pixels.
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1Nuox7mBJMGQt_QXZxmYGkXFEO5mjPf-B' />
# <figcaption>Image Caption</figcaption></center>
# </figure>
#
#
# Run the following code to load the dataset.

# %%
# Loading the dataset
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# %% [markdown]
# Change the index below and run the cell to visualize some examples in the dataset.

# %%
# Example of a picture
index = 1
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 0

# %% [markdown]
# # 3. Using One Hot encodings
#
# Many times in deep learning you will have a y vector with numbers ranging from 0 to C-1, where C is the number of classes. If C is for example 4, then you might have the following y vector which you will need to convert as follows:
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=1P02l9Fu2flQp0gsRl2bTAm0bsZ2cIMWI' />
# <figcaption>
# </figure>
#
#
#
# This is called a "one hot" encoding, because in the converted representation exactly one element of each column is "hot" (meaning set to 1). In tensorflow, we can tranform the labels of samples to one hot vectors by calling
#
# ```
# tf.keras.utils.to_categorical(y)
# ```
# Please transform the lables (or the output of the dataset) to one hot vectors.

# %% [markdown]
# As usual you flatten the image dataset, then normalize it by dividing by 255. On top of that, you will convert each label to a one-hot vector . Run the cell below to do so.

# %%
# Flatten the training and test images
X_train_flatten = X_train_orig.reshape(X_train_orig.shape[0], -1)
X_test_flatten = X_test_orig.reshape(X_test_orig.shape[0], -1)
# Normalize image vectors
X_train = X_train_flatten/255.
X_test = X_test_flatten/255.
# Flatten the training and test labels
Y_train_flatten=Y_train_orig.flatten()
Y_test_flatten=Y_test_orig.flatten()

# Convert training labels (Y_train_flatten) and test labels (Y_test_flatten) to one hot matrices\
### START CODE HERE ###'
Y_train = tf.keras.utils.to_categorical(Y_train_flatten)
Y_test = tf.keras.utils.to_categorical(Y_test_flatten)
### END CODE HERE ###

print ("number of training examples = " + str(X_train.shape[1]))
print ("number of test examples = " + str(X_test.shape[1]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 12288
# number of test examples = 12288
# X_train shape: (1080, 12288)
# Y_train shape: (1080, 6)
# X_test shape: (120, 12288)
# Y_test shape: (120, 6)

# %% [markdown]
# **Note** that 12288 comes from $64 \times 64 \times 3$. Each image is square, 64 by 64 pixels, and 3 is for the RGB colors. Please make sure all these shapes make sense to you before continuing.

# %% [markdown]
# #4.Building your model
#
# **Your goal** is to build an model capable of recognizing a sign with high accuracy. To do so, you are going to build a tensorflow model that is almost the same as one you have previously built for cat recognition and multi-class classification problems. If you already forget previous homeworks, please go back to review them to get some clues.
#
# **Previous related homeworks**
#
# "Planar_data_tensorflow.ipynb" in Homework 2
#
# "deepNN_tensorflow.ipynb" in Homework 3
#
# "regularized_deepNN_tensorflow.ipynb" in Homework 4
#
# "batch-size-test-student-version.ipynb" In Homework 5

# %%
### START CODE HERE ###
model=tf.keras.Sequential([
    #Input layer                      
    tf.keras.layers.Input(shape=(X_train.shape[1])), # Set how many elements are there in every training image?

    #Start adding hidden layers  
    tf.keras.layers.Dense(100, activation='relu'), # Please set your neuron numbers, activation function and so on. 

    #please feel free to add more hidden layers here. 
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dropout(0.35),
    tf.keras.layers.Dense(40, activation='relu'),
    tf.keras.layers.Dropout(0.35),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(30, activation='relu'),

    # End adding hidden layers 

    #output layer                   
    tf.keras.layers.Dense(6, activation='softmax') # Set how many elements are there in every training output
            
])
### END CODE HERE ###'
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 100)               1228900
#
#  dense_13 (Dense)            (None, 60)                6060
#
#  dropout_6 (Dropout)         (None, 60)                0
#
#  dense_14 (Dense)            (None, 40)                2440
#
#  dropout_7 (Dropout)         (None, 40)                0
#
#  dense_15 (Dense)            (None, 20)                820
#
#  dropout_8 (Dropout)         (None, 20)                0
#
#  dense_16 (Dense)            (None, 30)                630
#
#  dense_17 (Dense)            (None, 6)                 186
#
# =================================================================
# Total params: 1,239,036
# Trainable params: 1,239,036
# Non-trainable params: 0
# _________________________________________________________________

# %%
### START CODE HERE ###'
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),  # Optimizer. Please change 'None' to some meaningful learning rate which is usually <1
              loss= 'categorical_crossentropy', # loss. Please change 'None' to some meaningful loss
              # List of metrics to monitor
              metrics=['accuracy'],
                 )
### END CODE HERE ###'

# %%
### START CODE HERE ###'
history = model.fit(
    X_train , #  training input data
    Y_train, # training output data
    batch_size=32, # how many samples (points) do you want to use to update weights once? 
    epochs=5000,
    verbose=2 # how many iterations do you want to train your model? Your data will be reused to train the model for the number of epochs. I trained 5 min for this model
)
### END CODE HERE ###'
# Out:
# Epoch 1/5000
# 34/34 - 1s - loss: 1.9640 - accuracy: 0.1463 - 621ms/epoch - 18ms/step
# Epoch 2/5000
# 34/34 - 0s - loss: 1.8104 - accuracy: 0.1667 - 103ms/epoch - 3ms/step
# Epoch 3/5000
# 34/34 - 0s - loss: 1.7922 - accuracy: 0.1648 - 109ms/epoch - 3ms/step
# Epoch 4/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1667 - 116ms/epoch - 3ms/step
# Epoch 5/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1565 - 123ms/epoch - 4ms/step
# Epoch 6/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1593 - 117ms/epoch - 3ms/step
# Epoch 7/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1593 - 115ms/epoch - 3ms/step
# Epoch 8/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1648 - 109ms/epoch - 3ms/step
# Epoch 9/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 118ms/epoch - 3ms/step
# Epoch 10/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 117ms/epoch - 3ms/step
# Epoch 11/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1537 - 105ms/epoch - 3ms/step
# Epoch 12/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 13/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 114ms/epoch - 3ms/step
# Epoch 14/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1472 - 114ms/epoch - 3ms/step
# Epoch 15/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1667 - 117ms/epoch - 3ms/step
# Epoch 16/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1667 - 114ms/epoch - 3ms/step
# Epoch 17/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 114ms/epoch - 3ms/step
# Epoch 18/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 117ms/epoch - 3ms/step
# Epoch 19/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 108ms/epoch - 3ms/step
# Epoch 20/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 103ms/epoch - 3ms/step
# Epoch 21/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1481 - 121ms/epoch - 4ms/step
# Epoch 22/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 115ms/epoch - 3ms/step
# Epoch 23/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 109ms/epoch - 3ms/step
# Epoch 24/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 112ms/epoch - 3ms/step
# Epoch 25/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1602 - 106ms/epoch - 3ms/step
# Epoch 26/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1667 - 123ms/epoch - 4ms/step
# Epoch 27/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 118ms/epoch - 3ms/step
# Epoch 28/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1519 - 113ms/epoch - 3ms/step
# Epoch 29/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 110ms/epoch - 3ms/step
# Epoch 30/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 112ms/epoch - 3ms/step
# Epoch 31/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 112ms/epoch - 3ms/step
# Epoch 32/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 111ms/epoch - 3ms/step
# Epoch 33/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1370 - 114ms/epoch - 3ms/step
# Epoch 34/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1694 - 112ms/epoch - 3ms/step
# Epoch 35/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 120ms/epoch - 4ms/step
# Epoch 36/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 110ms/epoch - 3ms/step
# Epoch 37/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 108ms/epoch - 3ms/step
# Epoch 38/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 112ms/epoch - 3ms/step
# Epoch 39/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 115ms/epoch - 3ms/step
# Epoch 40/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 109ms/epoch - 3ms/step
# Epoch 41/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 42/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1343 - 111ms/epoch - 3ms/step
# Epoch 43/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 114ms/epoch - 3ms/step
# Epoch 44/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 122ms/epoch - 4ms/step
# Epoch 45/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 113ms/epoch - 3ms/step
# Epoch 46/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 115ms/epoch - 3ms/step
# Epoch 47/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 116ms/epoch - 3ms/step
# Epoch 48/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 120ms/epoch - 4ms/step
# Epoch 49/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 50/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 120ms/epoch - 4ms/step
# Epoch 51/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 52/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 120ms/epoch - 4ms/step
# Epoch 53/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 111ms/epoch - 3ms/step
# Epoch 54/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 111ms/epoch - 3ms/step
# Epoch 55/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 117ms/epoch - 3ms/step
# Epoch 56/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 57/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 111ms/epoch - 3ms/step
# Epoch 58/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 110ms/epoch - 3ms/step
# Epoch 59/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 113ms/epoch - 3ms/step
# Epoch 60/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 115ms/epoch - 3ms/step
# Epoch 61/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 124ms/epoch - 4ms/step
# Epoch 62/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 110ms/epoch - 3ms/step
# Epoch 63/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 116ms/epoch - 3ms/step
# Epoch 64/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 65/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 109ms/epoch - 3ms/step
# Epoch 66/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 110ms/epoch - 3ms/step
# Epoch 67/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1491 - 110ms/epoch - 3ms/step
# Epoch 68/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 116ms/epoch - 3ms/step
# Epoch 69/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 127ms/epoch - 4ms/step
# Epoch 70/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 114ms/epoch - 3ms/step
# Epoch 71/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 111ms/epoch - 3ms/step
# Epoch 72/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 114ms/epoch - 3ms/step
# Epoch 73/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1583 - 134ms/epoch - 4ms/step
# Epoch 74/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 113ms/epoch - 3ms/step
# Epoch 75/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 111ms/epoch - 3ms/step
# Epoch 76/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 115ms/epoch - 3ms/step
# Epoch 77/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 113ms/epoch - 3ms/step
# Epoch 78/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 122ms/epoch - 4ms/step
# Epoch 79/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 111ms/epoch - 3ms/step
# Epoch 80/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 109ms/epoch - 3ms/step
# Epoch 81/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 114ms/epoch - 3ms/step
# Epoch 82/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 112ms/epoch - 3ms/step
# Epoch 83/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 109ms/epoch - 3ms/step
# Epoch 84/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 106ms/epoch - 3ms/step
# Epoch 85/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 110ms/epoch - 3ms/step
# Epoch 86/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 112ms/epoch - 3ms/step
# Epoch 87/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 111ms/epoch - 3ms/step
# Epoch 88/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 108ms/epoch - 3ms/step
# Epoch 89/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 111ms/epoch - 3ms/step
# Epoch 90/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 111ms/epoch - 3ms/step
# Epoch 91/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 110ms/epoch - 3ms/step
# Epoch 92/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1380 - 112ms/epoch - 3ms/step
# Epoch 93/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 110ms/epoch - 3ms/step
# Epoch 94/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1361 - 115ms/epoch - 3ms/step
# Epoch 95/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 118ms/epoch - 3ms/step
# Epoch 96/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 105ms/epoch - 3ms/step
# Epoch 97/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 112ms/epoch - 3ms/step
# Epoch 98/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 112ms/epoch - 3ms/step
# Epoch 99/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 110ms/epoch - 3ms/step
# Epoch 100/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 101/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 119ms/epoch - 4ms/step
# Epoch 102/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 114ms/epoch - 3ms/step
# Epoch 103/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 113ms/epoch - 3ms/step
# Epoch 104/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 121ms/epoch - 4ms/step
# Epoch 105/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 108ms/epoch - 3ms/step
# Epoch 106/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1472 - 109ms/epoch - 3ms/step
# Epoch 107/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 113ms/epoch - 3ms/step
# Epoch 108/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 117ms/epoch - 3ms/step
# Epoch 109/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1398 - 112ms/epoch - 3ms/step
# Epoch 110/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 112ms/epoch - 3ms/step
# Epoch 111/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 106ms/epoch - 3ms/step
# Epoch 112/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 109ms/epoch - 3ms/step
# Epoch 113/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 118ms/epoch - 3ms/step
# Epoch 114/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 111ms/epoch - 3ms/step
# Epoch 115/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 114ms/epoch - 3ms/step
# Epoch 116/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 112ms/epoch - 3ms/step
# Epoch 117/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 107ms/epoch - 3ms/step
# Epoch 118/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 110ms/epoch - 3ms/step
# Epoch 119/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 110ms/epoch - 3ms/step
# Epoch 120/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 119ms/epoch - 3ms/step
# Epoch 121/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 120ms/epoch - 4ms/step
# Epoch 122/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1352 - 112ms/epoch - 3ms/step
# Epoch 123/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 113ms/epoch - 3ms/step
# Epoch 124/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 108ms/epoch - 3ms/step
# Epoch 125/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 110ms/epoch - 3ms/step
# Epoch 126/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 127/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 107ms/epoch - 3ms/step
# Epoch 128/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 108ms/epoch - 3ms/step
# Epoch 129/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 109ms/epoch - 3ms/step
# Epoch 130/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 126ms/epoch - 4ms/step
# Epoch 131/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 113ms/epoch - 3ms/step
# Epoch 132/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 116ms/epoch - 3ms/step
# Epoch 133/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 113ms/epoch - 3ms/step
# Epoch 134/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 109ms/epoch - 3ms/step
# Epoch 135/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 114ms/epoch - 3ms/step
# Epoch 136/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 110ms/epoch - 3ms/step
# Epoch 137/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 138/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 115ms/epoch - 3ms/step
# Epoch 139/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 116ms/epoch - 3ms/step
# Epoch 140/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 110ms/epoch - 3ms/step
# Epoch 141/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 111ms/epoch - 3ms/step
# Epoch 142/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 111ms/epoch - 3ms/step
# Epoch 143/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 112ms/epoch - 3ms/step
# Epoch 144/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 111ms/epoch - 3ms/step
# Epoch 145/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 109ms/epoch - 3ms/step
# Epoch 146/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 111ms/epoch - 3ms/step
# Epoch 147/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1398 - 122ms/epoch - 4ms/step
# Epoch 148/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1380 - 110ms/epoch - 3ms/step
# Epoch 149/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 106ms/epoch - 3ms/step
# Epoch 150/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 113ms/epoch - 3ms/step
# Epoch 151/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 110ms/epoch - 3ms/step
# Epoch 152/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1398 - 110ms/epoch - 3ms/step
# Epoch 153/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 107ms/epoch - 3ms/step
# Epoch 154/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 107ms/epoch - 3ms/step
# Epoch 155/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 116ms/epoch - 3ms/step
# Epoch 156/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 126ms/epoch - 4ms/step
# Epoch 157/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 110ms/epoch - 3ms/step
# Epoch 158/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 111ms/epoch - 3ms/step
# Epoch 159/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 112ms/epoch - 3ms/step
# Epoch 160/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 109ms/epoch - 3ms/step
# Epoch 161/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1426 - 105ms/epoch - 3ms/step
# Epoch 162/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 110ms/epoch - 3ms/step
# Epoch 163/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 116ms/epoch - 3ms/step
# Epoch 164/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 116ms/epoch - 3ms/step
# Epoch 165/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 124ms/epoch - 4ms/step
# Epoch 166/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 111ms/epoch - 3ms/step
# Epoch 167/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 110ms/epoch - 3ms/step
# Epoch 168/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 108ms/epoch - 3ms/step
# Epoch 169/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 107ms/epoch - 3ms/step
# Epoch 170/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 112ms/epoch - 3ms/step
# Epoch 171/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 124ms/epoch - 4ms/step
# Epoch 172/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 107ms/epoch - 3ms/step
# Epoch 173/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 117ms/epoch - 3ms/step
# Epoch 174/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 115ms/epoch - 3ms/step
# Epoch 175/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 113ms/epoch - 3ms/step
# Epoch 176/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1426 - 110ms/epoch - 3ms/step
# Epoch 177/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 114ms/epoch - 3ms/step
# Epoch 178/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 107ms/epoch - 3ms/step
# Epoch 179/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 114ms/epoch - 3ms/step
# Epoch 180/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 118ms/epoch - 3ms/step
# Epoch 181/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 114ms/epoch - 3ms/step
# Epoch 182/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 113ms/epoch - 3ms/step
# Epoch 183/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 108ms/epoch - 3ms/step
# Epoch 184/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 113ms/epoch - 3ms/step
# Epoch 185/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 113ms/epoch - 3ms/step
# Epoch 186/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 111ms/epoch - 3ms/step
# Epoch 187/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 112ms/epoch - 3ms/step
# Epoch 188/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1593 - 110ms/epoch - 3ms/step
# Epoch 189/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 108ms/epoch - 3ms/step
# Epoch 190/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 115ms/epoch - 3ms/step
# Epoch 191/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 117ms/epoch - 3ms/step
# Epoch 192/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 112ms/epoch - 3ms/step
# Epoch 193/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 112ms/epoch - 3ms/step
# Epoch 194/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 109ms/epoch - 3ms/step
# Epoch 195/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 109ms/epoch - 3ms/step
# Epoch 196/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 114ms/epoch - 3ms/step
# Epoch 197/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 106ms/epoch - 3ms/step
# Epoch 198/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 117ms/epoch - 3ms/step
# Epoch 199/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 115ms/epoch - 3ms/step
# Epoch 200/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 113ms/epoch - 3ms/step
# Epoch 201/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1343 - 110ms/epoch - 3ms/step
# Epoch 202/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 115ms/epoch - 3ms/step
# Epoch 203/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 111ms/epoch - 3ms/step
# Epoch 204/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 105ms/epoch - 3ms/step
# Epoch 205/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 108ms/epoch - 3ms/step
# Epoch 206/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 108ms/epoch - 3ms/step
# Epoch 207/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 113ms/epoch - 3ms/step
# Epoch 208/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 122ms/epoch - 4ms/step
# Epoch 209/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 111ms/epoch - 3ms/step
# Epoch 210/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 106ms/epoch - 3ms/step
# Epoch 211/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 112ms/epoch - 3ms/step
# Epoch 212/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 112ms/epoch - 3ms/step
# Epoch 213/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 111ms/epoch - 3ms/step
# Epoch 214/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 215/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1343 - 113ms/epoch - 3ms/step
# Epoch 216/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 110ms/epoch - 3ms/step
# Epoch 217/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 118ms/epoch - 3ms/step
# Epoch 218/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 114ms/epoch - 3ms/step
# Epoch 219/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 107ms/epoch - 3ms/step
# Epoch 220/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 108ms/epoch - 3ms/step
# Epoch 221/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 114ms/epoch - 3ms/step
# Epoch 222/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 112ms/epoch - 3ms/step
# Epoch 223/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 110ms/epoch - 3ms/step
# Epoch 224/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 110ms/epoch - 3ms/step
# Epoch 225/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 108ms/epoch - 3ms/step
# Epoch 226/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 125ms/epoch - 4ms/step
# Epoch 227/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1481 - 113ms/epoch - 3ms/step
# Epoch 228/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 113ms/epoch - 3ms/step
# Epoch 229/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1565 - 117ms/epoch - 3ms/step
# Epoch 230/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 108ms/epoch - 3ms/step
# Epoch 231/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1426 - 111ms/epoch - 3ms/step
# Epoch 232/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 116ms/epoch - 3ms/step
# Epoch 233/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 111ms/epoch - 3ms/step
# Epoch 234/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 124ms/epoch - 4ms/step
# Epoch 235/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 109ms/epoch - 3ms/step
# Epoch 236/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 108ms/epoch - 3ms/step
# Epoch 237/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 114ms/epoch - 3ms/step
# Epoch 238/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 112ms/epoch - 3ms/step
# Epoch 239/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 110ms/epoch - 3ms/step
# Epoch 240/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 114ms/epoch - 3ms/step
# Epoch 241/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 109ms/epoch - 3ms/step
# Epoch 242/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1685 - 108ms/epoch - 3ms/step
# Epoch 243/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 119ms/epoch - 3ms/step
# Epoch 244/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 110ms/epoch - 3ms/step
# Epoch 245/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 108ms/epoch - 3ms/step
# Epoch 246/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 110ms/epoch - 3ms/step
# Epoch 247/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 114ms/epoch - 3ms/step
# Epoch 248/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 132ms/epoch - 4ms/step
# Epoch 249/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 108ms/epoch - 3ms/step
# Epoch 250/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 112ms/epoch - 3ms/step
# Epoch 251/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 125ms/epoch - 4ms/step
# Epoch 252/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1667 - 112ms/epoch - 3ms/step
# Epoch 253/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1537 - 112ms/epoch - 3ms/step
# Epoch 254/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 110ms/epoch - 3ms/step
# Epoch 255/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 110ms/epoch - 3ms/step
# Epoch 256/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 112ms/epoch - 3ms/step
# Epoch 257/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 112ms/epoch - 3ms/step
# Epoch 258/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 109ms/epoch - 3ms/step
# Epoch 259/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 108ms/epoch - 3ms/step
# Epoch 260/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 123ms/epoch - 4ms/step
# Epoch 261/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 112ms/epoch - 3ms/step
# Epoch 262/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1565 - 109ms/epoch - 3ms/step
# Epoch 263/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 264/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 106ms/epoch - 3ms/step
# Epoch 265/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 109ms/epoch - 3ms/step
# Epoch 266/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 114ms/epoch - 3ms/step
# Epoch 267/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 106ms/epoch - 3ms/step
# Epoch 268/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 113ms/epoch - 3ms/step
# Epoch 269/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 119ms/epoch - 3ms/step
# Epoch 270/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1463 - 110ms/epoch - 3ms/step
# Epoch 271/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 114ms/epoch - 3ms/step
# Epoch 272/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1509 - 105ms/epoch - 3ms/step
# Epoch 273/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 107ms/epoch - 3ms/step
# Epoch 274/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 106ms/epoch - 3ms/step
# Epoch 275/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 111ms/epoch - 3ms/step
# Epoch 276/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 114ms/epoch - 3ms/step
# Epoch 277/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 124ms/epoch - 4ms/step
# Epoch 278/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 113ms/epoch - 3ms/step
# Epoch 279/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 110ms/epoch - 3ms/step
# Epoch 280/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 108ms/epoch - 3ms/step
# Epoch 281/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 112ms/epoch - 3ms/step
# Epoch 282/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 111ms/epoch - 3ms/step
# Epoch 283/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 113ms/epoch - 3ms/step
# Epoch 284/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 106ms/epoch - 3ms/step
# Epoch 285/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 113ms/epoch - 3ms/step
# Epoch 286/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 120ms/epoch - 4ms/step
# Epoch 287/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 116ms/epoch - 3ms/step
# Epoch 288/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 113ms/epoch - 3ms/step
# Epoch 289/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 120ms/epoch - 4ms/step
# Epoch 290/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 107ms/epoch - 3ms/step
# Epoch 291/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 109ms/epoch - 3ms/step
# Epoch 292/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 113ms/epoch - 3ms/step
# Epoch 293/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 118ms/epoch - 3ms/step
# Epoch 294/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 121ms/epoch - 4ms/step
# Epoch 295/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 107ms/epoch - 3ms/step
# Epoch 296/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 112ms/epoch - 3ms/step
# Epoch 297/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 107ms/epoch - 3ms/step
# Epoch 298/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 299/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 114ms/epoch - 3ms/step
# Epoch 300/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 113ms/epoch - 3ms/step
# Epoch 301/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 111ms/epoch - 3ms/step
# Epoch 302/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 111ms/epoch - 3ms/step
# Epoch 303/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1676 - 118ms/epoch - 3ms/step
# Epoch 304/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 305/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 106ms/epoch - 3ms/step
# Epoch 306/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 113ms/epoch - 3ms/step
# Epoch 307/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 119ms/epoch - 3ms/step
# Epoch 308/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 119ms/epoch - 4ms/step
# Epoch 309/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 115ms/epoch - 3ms/step
# Epoch 310/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 111ms/epoch - 3ms/step
# Epoch 311/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 114ms/epoch - 3ms/step
# Epoch 312/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 133ms/epoch - 4ms/step
# Epoch 313/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 112ms/epoch - 3ms/step
# Epoch 314/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1694 - 110ms/epoch - 3ms/step
# Epoch 315/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 112ms/epoch - 3ms/step
# Epoch 316/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 115ms/epoch - 3ms/step
# Epoch 317/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 110ms/epoch - 3ms/step
# Epoch 318/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 118ms/epoch - 3ms/step
# Epoch 319/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 113ms/epoch - 3ms/step
# Epoch 320/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 120ms/epoch - 4ms/step
# Epoch 321/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 109ms/epoch - 3ms/step
# Epoch 322/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 109ms/epoch - 3ms/step
# Epoch 323/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 114ms/epoch - 3ms/step
# Epoch 324/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 114ms/epoch - 3ms/step
# Epoch 325/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 116ms/epoch - 3ms/step
# Epoch 326/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 113ms/epoch - 3ms/step
# Epoch 327/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 113ms/epoch - 3ms/step
# Epoch 328/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 111ms/epoch - 3ms/step
# Epoch 329/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 125ms/epoch - 4ms/step
# Epoch 330/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 111ms/epoch - 3ms/step
# Epoch 331/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 332/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 109ms/epoch - 3ms/step
# Epoch 333/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 108ms/epoch - 3ms/step
# Epoch 334/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 131ms/epoch - 4ms/step
# Epoch 335/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 116ms/epoch - 3ms/step
# Epoch 336/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 116ms/epoch - 3ms/step
# Epoch 337/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 122ms/epoch - 4ms/step
# Epoch 338/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 122ms/epoch - 4ms/step
# Epoch 339/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 111ms/epoch - 3ms/step
# Epoch 340/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 108ms/epoch - 3ms/step
# Epoch 341/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 114ms/epoch - 3ms/step
# Epoch 342/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 113ms/epoch - 3ms/step
# Epoch 343/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 114ms/epoch - 3ms/step
# Epoch 344/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 118ms/epoch - 3ms/step
# Epoch 345/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 112ms/epoch - 3ms/step
# Epoch 346/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 121ms/epoch - 4ms/step
# Epoch 347/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 113ms/epoch - 3ms/step
# Epoch 348/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 112ms/epoch - 3ms/step
# Epoch 349/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 115ms/epoch - 3ms/step
# Epoch 350/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 108ms/epoch - 3ms/step
# Epoch 351/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1556 - 109ms/epoch - 3ms/step
# Epoch 352/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 112ms/epoch - 3ms/step
# Epoch 353/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 111ms/epoch - 3ms/step
# Epoch 354/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 116ms/epoch - 3ms/step
# Epoch 355/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 110ms/epoch - 3ms/step
# Epoch 356/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 111ms/epoch - 3ms/step
# Epoch 357/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1370 - 111ms/epoch - 3ms/step
# Epoch 358/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 111ms/epoch - 3ms/step
# Epoch 359/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 110ms/epoch - 3ms/step
# Epoch 360/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 114ms/epoch - 3ms/step
# Epoch 361/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1370 - 116ms/epoch - 3ms/step
# Epoch 362/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 113ms/epoch - 3ms/step
# Epoch 363/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 118ms/epoch - 3ms/step
# Epoch 364/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 113ms/epoch - 3ms/step
# Epoch 365/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 109ms/epoch - 3ms/step
# Epoch 366/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 111ms/epoch - 3ms/step
# Epoch 367/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 113ms/epoch - 3ms/step
# Epoch 368/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1546 - 113ms/epoch - 3ms/step
# Epoch 369/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 116ms/epoch - 3ms/step
# Epoch 370/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 109ms/epoch - 3ms/step
# Epoch 371/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 120ms/epoch - 4ms/step
# Epoch 372/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 112ms/epoch - 3ms/step
# Epoch 373/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 119ms/epoch - 4ms/step
# Epoch 374/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 117ms/epoch - 3ms/step
# Epoch 375/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 114ms/epoch - 3ms/step
# Epoch 376/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 105ms/epoch - 3ms/step
# Epoch 377/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 111ms/epoch - 3ms/step
# Epoch 378/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 108ms/epoch - 3ms/step
# Epoch 379/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 112ms/epoch - 3ms/step
# Epoch 380/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 118ms/epoch - 3ms/step
# Epoch 381/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 122ms/epoch - 4ms/step
# Epoch 382/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 119ms/epoch - 4ms/step
# Epoch 383/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 116ms/epoch - 3ms/step
# Epoch 384/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 109ms/epoch - 3ms/step
# Epoch 385/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 113ms/epoch - 3ms/step
# Epoch 386/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1685 - 112ms/epoch - 3ms/step
# Epoch 387/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 109ms/epoch - 3ms/step
# Epoch 388/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 117ms/epoch - 3ms/step
# Epoch 389/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1370 - 118ms/epoch - 3ms/step
# Epoch 390/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 118ms/epoch - 3ms/step
# Epoch 391/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1398 - 115ms/epoch - 3ms/step
# Epoch 392/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 119ms/epoch - 4ms/step
# Epoch 393/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 119ms/epoch - 3ms/step
# Epoch 394/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 119ms/epoch - 3ms/step
# Epoch 395/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 110ms/epoch - 3ms/step
# Epoch 396/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 114ms/epoch - 3ms/step
# Epoch 397/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 117ms/epoch - 3ms/step
# Epoch 398/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 106ms/epoch - 3ms/step
# Epoch 399/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 114ms/epoch - 3ms/step
# Epoch 400/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 116ms/epoch - 3ms/step
# Epoch 401/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 113ms/epoch - 3ms/step
# Epoch 402/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1398 - 111ms/epoch - 3ms/step
# Epoch 403/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 108ms/epoch - 3ms/step
# Epoch 404/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 111ms/epoch - 3ms/step
# Epoch 405/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1426 - 120ms/epoch - 4ms/step
# Epoch 406/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 115ms/epoch - 3ms/step
# Epoch 407/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 114ms/epoch - 3ms/step
# Epoch 408/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 110ms/epoch - 3ms/step
# Epoch 409/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 107ms/epoch - 3ms/step
# Epoch 410/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 411/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 114ms/epoch - 3ms/step
# Epoch 412/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 115ms/epoch - 3ms/step
# Epoch 413/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 117ms/epoch - 3ms/step
# Epoch 414/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 122ms/epoch - 4ms/step
# Epoch 415/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 117ms/epoch - 3ms/step
# Epoch 416/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 118ms/epoch - 3ms/step
# Epoch 417/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 118ms/epoch - 3ms/step
# Epoch 418/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 120ms/epoch - 4ms/step
# Epoch 419/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 124ms/epoch - 4ms/step
# Epoch 420/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1602 - 110ms/epoch - 3ms/step
# Epoch 421/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1463 - 113ms/epoch - 3ms/step
# Epoch 422/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 119ms/epoch - 4ms/step
# Epoch 423/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1370 - 117ms/epoch - 3ms/step
# Epoch 424/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 120ms/epoch - 4ms/step
# Epoch 425/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 110ms/epoch - 3ms/step
# Epoch 426/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 109ms/epoch - 3ms/step
# Epoch 427/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 116ms/epoch - 3ms/step
# Epoch 428/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 111ms/epoch - 3ms/step
# Epoch 429/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 110ms/epoch - 3ms/step
# Epoch 430/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 114ms/epoch - 3ms/step
# Epoch 431/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 119ms/epoch - 3ms/step
# Epoch 432/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1704 - 119ms/epoch - 3ms/step
# Epoch 433/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 107ms/epoch - 3ms/step
# Epoch 434/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 113ms/epoch - 3ms/step
# Epoch 435/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1491 - 117ms/epoch - 3ms/step
# Epoch 436/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 108ms/epoch - 3ms/step
# Epoch 437/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 116ms/epoch - 3ms/step
# Epoch 438/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 110ms/epoch - 3ms/step
# Epoch 439/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1361 - 121ms/epoch - 4ms/step
# Epoch 440/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 114ms/epoch - 3ms/step
# Epoch 441/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 110ms/epoch - 3ms/step
# Epoch 442/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 116ms/epoch - 3ms/step
# Epoch 443/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1676 - 116ms/epoch - 3ms/step
# Epoch 444/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 115ms/epoch - 3ms/step
# Epoch 445/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 107ms/epoch - 3ms/step
# Epoch 446/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 106ms/epoch - 3ms/step
# Epoch 447/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 110ms/epoch - 3ms/step
# Epoch 448/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 117ms/epoch - 3ms/step
# Epoch 449/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 109ms/epoch - 3ms/step
# Epoch 450/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 113ms/epoch - 3ms/step
# Epoch 451/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 108ms/epoch - 3ms/step
# Epoch 452/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 111ms/epoch - 3ms/step
# Epoch 453/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 113ms/epoch - 3ms/step
# Epoch 454/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 111ms/epoch - 3ms/step
# Epoch 455/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1463 - 112ms/epoch - 3ms/step
# Epoch 456/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 110ms/epoch - 3ms/step
# Epoch 457/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 122ms/epoch - 4ms/step
# Epoch 458/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 112ms/epoch - 3ms/step
# Epoch 459/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 107ms/epoch - 3ms/step
# Epoch 460/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 106ms/epoch - 3ms/step
# Epoch 461/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1593 - 110ms/epoch - 3ms/step
# Epoch 462/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1444 - 110ms/epoch - 3ms/step
# Epoch 463/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 113ms/epoch - 3ms/step
# Epoch 464/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 114ms/epoch - 3ms/step
# Epoch 465/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 125ms/epoch - 4ms/step
# Epoch 466/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 112ms/epoch - 3ms/step
# Epoch 467/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 468/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 105ms/epoch - 3ms/step
# Epoch 469/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 116ms/epoch - 3ms/step
# Epoch 470/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 118ms/epoch - 3ms/step
# Epoch 471/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 111ms/epoch - 3ms/step
# Epoch 472/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 110ms/epoch - 3ms/step
# Epoch 473/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 113ms/epoch - 3ms/step
# Epoch 474/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1500 - 121ms/epoch - 4ms/step
# Epoch 475/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 122ms/epoch - 4ms/step
# Epoch 476/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 107ms/epoch - 3ms/step
# Epoch 477/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1426 - 115ms/epoch - 3ms/step
# Epoch 478/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 114ms/epoch - 3ms/step
# Epoch 479/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 109ms/epoch - 3ms/step
# Epoch 480/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1565 - 115ms/epoch - 3ms/step
# Epoch 481/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 106ms/epoch - 3ms/step
# Epoch 482/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 124ms/epoch - 4ms/step
# Epoch 483/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 114ms/epoch - 3ms/step
# Epoch 484/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 112ms/epoch - 3ms/step
# Epoch 485/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 110ms/epoch - 3ms/step
# Epoch 486/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 113ms/epoch - 3ms/step
# Epoch 487/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 114ms/epoch - 3ms/step
# Epoch 488/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1380 - 110ms/epoch - 3ms/step
# Epoch 489/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1454 - 106ms/epoch - 3ms/step
# Epoch 490/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 111ms/epoch - 3ms/step
# Epoch 491/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 122ms/epoch - 4ms/step
# Epoch 492/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 115ms/epoch - 3ms/step
# Epoch 493/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 109ms/epoch - 3ms/step
# Epoch 494/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 110ms/epoch - 3ms/step
# Epoch 495/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 114ms/epoch - 3ms/step
# Epoch 496/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 113ms/epoch - 3ms/step
# Epoch 497/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1380 - 111ms/epoch - 3ms/step
# Epoch 498/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 118ms/epoch - 3ms/step
# Epoch 499/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 119ms/epoch - 4ms/step
# Epoch 500/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 120ms/epoch - 4ms/step
# Epoch 501/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 115ms/epoch - 3ms/step
# Epoch 502/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 112ms/epoch - 3ms/step
# Epoch 503/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 116ms/epoch - 3ms/step
# Epoch 504/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 127ms/epoch - 4ms/step
# Epoch 505/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1611 - 112ms/epoch - 3ms/step
# Epoch 506/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 108ms/epoch - 3ms/step
# Epoch 507/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 111ms/epoch - 3ms/step
# Epoch 508/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 134ms/epoch - 4ms/step
# Epoch 509/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 113ms/epoch - 3ms/step
# Epoch 510/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1491 - 110ms/epoch - 3ms/step
# Epoch 511/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 117ms/epoch - 3ms/step
# Epoch 512/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 110ms/epoch - 3ms/step
# Epoch 513/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 117ms/epoch - 3ms/step
# Epoch 514/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 113ms/epoch - 3ms/step
# Epoch 515/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 107ms/epoch - 3ms/step
# Epoch 516/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 117ms/epoch - 3ms/step
# Epoch 517/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 110ms/epoch - 3ms/step
# Epoch 518/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 108ms/epoch - 3ms/step
# Epoch 519/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 110ms/epoch - 3ms/step
# Epoch 520/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 116ms/epoch - 3ms/step
# Epoch 521/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 522/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 111ms/epoch - 3ms/step
# Epoch 523/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 113ms/epoch - 3ms/step
# Epoch 524/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 108ms/epoch - 3ms/step
# Epoch 525/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 126ms/epoch - 4ms/step
# Epoch 526/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1315 - 115ms/epoch - 3ms/step
# Epoch 527/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 113ms/epoch - 3ms/step
# Epoch 528/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 529/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 113ms/epoch - 3ms/step
# Epoch 530/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 115ms/epoch - 3ms/step
# Epoch 531/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 114ms/epoch - 3ms/step
# Epoch 532/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 103ms/epoch - 3ms/step
# Epoch 533/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 116ms/epoch - 3ms/step
# Epoch 534/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 118ms/epoch - 3ms/step
# Epoch 535/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 105ms/epoch - 3ms/step
# Epoch 536/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 108ms/epoch - 3ms/step
# Epoch 537/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1324 - 104ms/epoch - 3ms/step
# Epoch 538/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 106ms/epoch - 3ms/step
# Epoch 539/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 540/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 113ms/epoch - 3ms/step
# Epoch 541/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 113ms/epoch - 3ms/step
# Epoch 542/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 125ms/epoch - 4ms/step
# Epoch 543/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 106ms/epoch - 3ms/step
# Epoch 544/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 110ms/epoch - 3ms/step
# Epoch 545/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 118ms/epoch - 3ms/step
# Epoch 546/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1556 - 112ms/epoch - 3ms/step
# Epoch 547/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 109ms/epoch - 3ms/step
# Epoch 548/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 111ms/epoch - 3ms/step
# Epoch 549/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 106ms/epoch - 3ms/step
# Epoch 550/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 109ms/epoch - 3ms/step
# Epoch 551/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 120ms/epoch - 4ms/step
# Epoch 552/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 553/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 105ms/epoch - 3ms/step
# Epoch 554/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1472 - 110ms/epoch - 3ms/step
# Epoch 555/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1343 - 115ms/epoch - 3ms/step
# Epoch 556/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1398 - 109ms/epoch - 3ms/step
# Epoch 557/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 114ms/epoch - 3ms/step
# Epoch 558/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 106ms/epoch - 3ms/step
# Epoch 559/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 560/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 122ms/epoch - 4ms/step
# Epoch 561/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1583 - 110ms/epoch - 3ms/step
# Epoch 562/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1583 - 112ms/epoch - 3ms/step
# Epoch 563/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 107ms/epoch - 3ms/step
# Epoch 564/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1500 - 120ms/epoch - 4ms/step
# Epoch 565/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 117ms/epoch - 3ms/step
# Epoch 566/5000
# ...
# Epoch 584/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1343 - 118ms/epoch - 3ms/step
# Epoch 585/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 117ms/epoch - 3ms/step
# Epoch 586/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 119ms/epoch - 3ms/step
# Epoch 587/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 114ms/epoch - 3ms/step
# Epoch 588/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 121ms/epoch - 4ms/step
# Epoch 589/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 130ms/epoch - 4ms/step
# Epoch 590/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 591/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 106ms/epoch - 3ms/step
# Epoch 592/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 593/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 116ms/epoch - 3ms/step
# Epoch 594/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1315 - 120ms/epoch - 4ms/step
# Epoch 595/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 109ms/epoch - 3ms/step
# Epoch 596/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 111ms/epoch - 3ms/step
# Epoch 597/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 110ms/epoch - 3ms/step
# Epoch 598/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 119ms/epoch - 3ms/step
# Epoch 599/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 113ms/epoch - 3ms/step
# Epoch 600/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 111ms/epoch - 3ms/step
# Epoch 601/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 111ms/epoch - 3ms/step
# Epoch 602/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 121ms/epoch - 4ms/step
# Epoch 603/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 118ms/epoch - 3ms/step
# Epoch 604/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 605/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1556 - 109ms/epoch - 3ms/step
# Epoch 606/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 113ms/epoch - 3ms/step
# Epoch 607/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 108ms/epoch - 3ms/step
# Epoch 608/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 116ms/epoch - 3ms/step
# Epoch 609/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 112ms/epoch - 3ms/step
# Epoch 610/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 110ms/epoch - 3ms/step
# Epoch 611/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 119ms/epoch - 3ms/step
# Epoch 612/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1361 - 108ms/epoch - 3ms/step
# Epoch 613/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 115ms/epoch - 3ms/step
# Epoch 614/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 115ms/epoch - 3ms/step
# Epoch 615/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1361 - 111ms/epoch - 3ms/step
# Epoch 616/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1426 - 112ms/epoch - 3ms/step
# Epoch 617/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 108ms/epoch - 3ms/step
# Epoch 618/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 113ms/epoch - 3ms/step
# Epoch 619/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 114ms/epoch - 3ms/step
# Epoch 620/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 116ms/epoch - 3ms/step
# Epoch 621/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 110ms/epoch - 3ms/step
# Epoch 622/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1389 - 105ms/epoch - 3ms/step
# Epoch 623/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 107ms/epoch - 3ms/step
# Epoch 624/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 112ms/epoch - 3ms/step
# Epoch 625/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 114ms/epoch - 3ms/step
# Epoch 626/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 627/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 113ms/epoch - 3ms/step
# Epoch 628/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 115ms/epoch - 3ms/step
# Epoch 629/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 117ms/epoch - 3ms/step
# Epoch 630/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 109ms/epoch - 3ms/step
# Epoch 631/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1380 - 108ms/epoch - 3ms/step
# Epoch 632/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 112ms/epoch - 3ms/step
# Epoch 633/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 106ms/epoch - 3ms/step
# Epoch 634/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 110ms/epoch - 3ms/step
# Epoch 635/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 119ms/epoch - 3ms/step
# Epoch 636/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 111ms/epoch - 3ms/step
# Epoch 637/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 121ms/epoch - 4ms/step
# Epoch 638/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 112ms/epoch - 3ms/step
# Epoch 639/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 640/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 641/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 114ms/epoch - 3ms/step
# Epoch 642/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 112ms/epoch - 3ms/step
# Epoch 643/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1657 - 114ms/epoch - 3ms/step
# Epoch 644/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 645/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 124ms/epoch - 4ms/step
# Epoch 646/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 117ms/epoch - 3ms/step
# Epoch 647/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 111ms/epoch - 3ms/step
# Epoch 648/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 649/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 112ms/epoch - 3ms/step
# Epoch 650/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 102ms/epoch - 3ms/step
# Epoch 651/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 114ms/epoch - 3ms/step
# Epoch 652/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1398 - 111ms/epoch - 3ms/step
# Epoch 653/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 109ms/epoch - 3ms/step
# Epoch 654/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 120ms/epoch - 4ms/step
# Epoch 655/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1676 - 107ms/epoch - 3ms/step
# Epoch 656/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 112ms/epoch - 3ms/step
# Epoch 657/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 120ms/epoch - 4ms/step
# Epoch 658/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 117ms/epoch - 3ms/step
# Epoch 659/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 122ms/epoch - 4ms/step
# Epoch 660/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 123ms/epoch - 4ms/step
# Epoch 661/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 115ms/epoch - 3ms/step
# Epoch 662/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 121ms/epoch - 4ms/step
# Epoch 663/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 112ms/epoch - 3ms/step
# Epoch 664/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 118ms/epoch - 3ms/step
# Epoch 665/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1417 - 114ms/epoch - 3ms/step
# Epoch 666/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 110ms/epoch - 3ms/step
# Epoch 667/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 116ms/epoch - 3ms/step
# Epoch 668/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 110ms/epoch - 3ms/step
# Epoch 669/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 114ms/epoch - 3ms/step
# Epoch 670/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 112ms/epoch - 3ms/step
# Epoch 671/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1472 - 128ms/epoch - 4ms/step
# Epoch 672/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 112ms/epoch - 3ms/step
# Epoch 673/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1333 - 111ms/epoch - 3ms/step
# Epoch 674/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 113ms/epoch - 3ms/step
# Epoch 675/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1370 - 127ms/epoch - 4ms/step
# Epoch 676/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 115ms/epoch - 3ms/step
# Epoch 677/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 121ms/epoch - 4ms/step
# Epoch 678/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 112ms/epoch - 3ms/step
# Epoch 679/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 123ms/epoch - 4ms/step
# Epoch 680/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 108ms/epoch - 3ms/step
# Epoch 681/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 110ms/epoch - 3ms/step
# Epoch 682/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 111ms/epoch - 3ms/step
# Epoch 683/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 108ms/epoch - 3ms/step
# Epoch 684/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 117ms/epoch - 3ms/step
# Epoch 685/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 110ms/epoch - 3ms/step
# Epoch 686/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 111ms/epoch - 3ms/step
# Epoch 687/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 112ms/epoch - 3ms/step
# Epoch 688/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 121ms/epoch - 4ms/step
# Epoch 689/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1426 - 112ms/epoch - 3ms/step
# Epoch 690/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 691/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 107ms/epoch - 3ms/step
# Epoch 692/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 115ms/epoch - 3ms/step
# Epoch 693/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 112ms/epoch - 3ms/step
# Epoch 694/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 109ms/epoch - 3ms/step
# Epoch 695/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1454 - 113ms/epoch - 3ms/step
# Epoch 696/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 119ms/epoch - 4ms/step
# Epoch 697/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 117ms/epoch - 3ms/step
# Epoch 698/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 112ms/epoch - 3ms/step
# Epoch 699/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 111ms/epoch - 3ms/step
# Epoch 700/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 110ms/epoch - 3ms/step
# Epoch 701/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1519 - 109ms/epoch - 3ms/step
# Epoch 702/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 110ms/epoch - 3ms/step
# Epoch 703/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 118ms/epoch - 3ms/step
# Epoch 704/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 119ms/epoch - 3ms/step
# Epoch 705/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 121ms/epoch - 4ms/step
# Epoch 706/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 106ms/epoch - 3ms/step
# Epoch 707/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1639 - 113ms/epoch - 3ms/step
# Epoch 708/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 112ms/epoch - 3ms/step
# Epoch 709/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 116ms/epoch - 3ms/step
# Epoch 710/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 117ms/epoch - 3ms/step
# Epoch 711/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 108ms/epoch - 3ms/step
# Epoch 712/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 115ms/epoch - 3ms/step
# Epoch 713/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1583 - 119ms/epoch - 4ms/step
# Epoch 714/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 111ms/epoch - 3ms/step
# Epoch 715/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 112ms/epoch - 3ms/step
# Epoch 716/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 109ms/epoch - 3ms/step
# Epoch 717/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 103ms/epoch - 3ms/step
# Epoch 718/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 116ms/epoch - 3ms/step
# Epoch 719/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 114ms/epoch - 3ms/step
# Epoch 720/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 721/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 107ms/epoch - 3ms/step
# Epoch 722/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1491 - 129ms/epoch - 4ms/step
# Epoch 723/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1444 - 113ms/epoch - 3ms/step
# Epoch 724/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 114ms/epoch - 3ms/step
# Epoch 725/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 111ms/epoch - 3ms/step
# Epoch 726/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 113ms/epoch - 3ms/step
# Epoch 727/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 114ms/epoch - 3ms/step
# Epoch 728/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 111ms/epoch - 3ms/step
# Epoch 729/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 110ms/epoch - 3ms/step
# Epoch 730/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1435 - 105ms/epoch - 3ms/step
# Epoch 731/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1463 - 124ms/epoch - 4ms/step
# Epoch 732/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1389 - 111ms/epoch - 3ms/step
# Epoch 733/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 734/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1574 - 110ms/epoch - 3ms/step
# Epoch 735/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 111ms/epoch - 3ms/step
# Epoch 736/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 117ms/epoch - 3ms/step
# Epoch 737/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1602 - 114ms/epoch - 3ms/step
# Epoch 738/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 116ms/epoch - 3ms/step
# Epoch 739/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1481 - 123ms/epoch - 4ms/step
# Epoch 740/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 111ms/epoch - 3ms/step
# Epoch 741/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 108ms/epoch - 3ms/step
# Epoch 742/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 110ms/epoch - 3ms/step
# Epoch 743/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1556 - 111ms/epoch - 3ms/step
# Epoch 744/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 112ms/epoch - 3ms/step
# Epoch 745/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1546 - 114ms/epoch - 3ms/step
# Epoch 746/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 109ms/epoch - 3ms/step
# Epoch 747/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 113ms/epoch - 3ms/step
# Epoch 748/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 124ms/epoch - 4ms/step
# Epoch 749/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1537 - 112ms/epoch - 3ms/step
# Epoch 750/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 109ms/epoch - 3ms/step
# Epoch 751/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1463 - 114ms/epoch - 3ms/step
# Epoch 752/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1593 - 112ms/epoch - 3ms/step
# Epoch 753/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1500 - 121ms/epoch - 4ms/step
# Epoch 754/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1602 - 108ms/epoch - 3ms/step
# Epoch 755/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 110ms/epoch - 3ms/step
# Epoch 756/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1343 - 124ms/epoch - 4ms/step
# Epoch 757/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 112ms/epoch - 3ms/step
# Epoch 758/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1620 - 113ms/epoch - 3ms/step
# Epoch 759/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1407 - 108ms/epoch - 3ms/step
# Epoch 760/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1472 - 130ms/epoch - 4ms/step
# Epoch 761/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1667 - 113ms/epoch - 3ms/step
# Epoch 762/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1630 - 110ms/epoch - 3ms/step
# Epoch 763/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1611 - 120ms/epoch - 4ms/step
# Epoch 764/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1509 - 110ms/epoch - 3ms/step
# Epoch 765/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 118ms/epoch - 3ms/step
# Epoch 766/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1444 - 108ms/epoch - 3ms/step
# Epoch 767/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1500 - 115ms/epoch - 3ms/step
# Epoch 768/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1648 - 112ms/epoch - 3ms/step
# Epoch 769/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1565 - 115ms/epoch - 3ms/step
# Epoch 770/5000
# 34/34 - 0s - loss: 1.7919 - accuracy: 0.1463 - 106ms/epoch - 3ms/step
# Epoch 771/5000
# 34/34 - 0s - loss: 1.7918 - accuracy: 0.1528 - 108ms/epoch - 3ms/step

# %%
plt.plot(history.history['loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')

# %% [markdown]
# **If the training works, congratulations! You have built a model for recognizing SIGN language.**

# %%
_, train_accuracy = model.evaluate(X_train,Y_train)
_, test_accuracy = model.evaluate(X_test,Y_test)

print('The accuracy of the training dataset is: {}.'.format(train_accuracy))
print('The accuracy of the test dataset is {}.'.format(test_accuracy))

# %% [markdown]
# # 5. Grading rule
#
# ***Try your best to achieve high accuarcy.  The grade for this homework will based on your model final training accurracy and test accuracy. ***
#
# For example, if your final training accurracy is 87.8 (consider one decimal) and test accuracy is 70.9, the total grade is 8.78 + 7.09 =15.87. The full credit is 10+10 =20.  It is hard to get full credit in this homework, please try your best.

# %% [markdown]
# **Tips**
#
# You can try to improve its accuracy by:
# 1. tuning the hyperparameters (learning rate, batch size, epoches and so on)
# 2. adjusting your layers numbers or nuron numbers.
# 3. changing optimizer or loss function
# 4. using dropout layer
# 5. add regularizers.L2
# 6. .....

# %% [markdown]
# Once again, here's a thumbs up for your work!

# %%
# %pylab inline
import matplotlib.image as mpimg
img = mpimg.imread('images/thumbs_up.jpg')
imgplot = plt.imshow(img)
plt.show()
